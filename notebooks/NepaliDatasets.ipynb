# %%
import pandas as pd

# %%
df = pd.read_csv('setopati_kinmel.csv')

# %%
df.columns
# Out:
# Index(['author', 'content', 'news_url', 'published_date', 'title'], dtype='object')

# %%
df
# Out:
#                    author                                            content  \
# 0            नारायण खड्का  \n,फोनमा कुरा गर्दा ४० वर्षीया किसान मनकुमारी ...
# 1      सेतोपाटी संवाददाता  \n,नेपाल उद्योग वाणिज्य महासंघका अध्यक्ष चन्द्...
# 2            नारायण खड्का  \n,दाङको तुलसीपुर उपमहानगरपालिकाले फोहोरबाट कम...
# 3                    रासस  \n,यो याममा जुम्लाको काँचो स्याउ बजारमा गएपछि ...
# 4                    रासस  \n,उद्योग, वाणिज्य तथा आपूर्तिमन्त्री रमेश रिज...
# ...                   ...                                                ...
# 32398  सेतोपाटी संवाददाता  \n,सरकारले २०८० साल भित्रै लगानी सम्मेलन गर्ने...
# 32399  सेतोपाटी संवाददाता  \n,सरकारले अबदेखि वैदेशिक लगानीको क्षेत्रगत सी...
# 32400  सेतोपाटी संवाददाता  \n,सरकारले कृषि क्षेत्रमा गरेको लगानी अनुसारको...
# 32401  सेतोपाटी संवाददाता  \n,लोक सेवा आयोगले पाँच सय १३ जनाका लागि शाखा ...
# 32402  सेतोपाटी संवाददाता  \n,झण्डै २० दिनको अन्तरालमा सेयर बजार परिसूचक ...
#
# ...
